# %% [markdown]
# <a href="https://colab.research.google.com/github/Prem-Stack/ADF-Incremental-Full-Load/blob/main/DataTypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### DataTypes

# %% [markdown]
# ### Variables

# %%
name = 'prem'   #String
age = 36      #integer
data_trainer = True   #Boolean
height = 5.7    #Float

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(data_trainer)
# Out:
# bool

# %%
type(height)
# Out:
# float

# %%
print(name)
# Out:
# prem

# %%
print(age)
# Out:
# 36

# %%
print(data_trainer)
# Out:
# True

# %%
paragraph = '''this is a long paragraph
it can span multiple lines.
Very useful for long text'''

print(paragraph)
type(paragraph)
# Out:
# this is a long paragraph
# it can span multiple lines.
# Very useful for long text
# str

# %%
paragraph = """this is a long paragraph
it can span multiple lines.
Very useful for long text"""

print(paragraph)
type(paragraph)
# Out:
# this is a long paragraph
# it can span multiple lines.
# Very useful for long text
# str

# %% [markdown]
# ## Using f-string (formatted strings)
#
# f-strings lets you embed variable inside a string easily.

# %%
f"{name} python class"
# Out:
# 'prem python class'

# %%
f"my name is {name} and im {age} year old"
# Out:
# 'my name is prem and im 36 year old'

# %% [markdown]
# ### Calculation inside string

# %%
x=10
y=20

print(f"{x} + {y} = {x + y}")
# Out:
# 10 + 20 = 30

# %%
first_name = "Prem"
last_name = "Chakkaravarthi"
Full_name = first_name + ' ' + last_name

print(f"My full name is {Full_name}")
# Out:
# My full name is Prem Chakkaravarthi

# %% [markdown]
# ### Repeating a separator

# %%
text = "+-*" * 10

print(text)
# Out:
# +-*+-*+-*+-*+-*+-*+-*+-*+-*+-*
